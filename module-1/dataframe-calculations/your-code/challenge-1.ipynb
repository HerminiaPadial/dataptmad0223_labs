# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **Pokemon**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](../images/pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# #### Import all required libraries.

# %%
# import libraries
import pandas as pd
import numpy as np
import re
import string
import cv2  ##

# %% [markdown]
# #### Import data set.
#
# Import data set `Pokemon` from Ironhack's database. Read the data into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
# import data set from Ironhack's database
imagen= cv2.imread('/Users/herminiapadialromera/ironhackb/dataptmad0223_labs/module-1/dataframe-calculations/images/pokemon.jpg')

# %%
pokemon= pd.DataFrame(imagen.reshape(-1, 3), columns=["R", "G", "B"])
type(pokemon)
# Out:
# pandas.core.frame.DataFrame

# %%
pokemon.head()
# Out:
#      R    G   B
# 0  201  131  40
# 1  201  131  40
# 2  201  131  40
# 3  201  131  40
# 4  201  131  40

# %% [markdown]
# #### Print first 10 rows of `pokemon`.

# %%
pokemon.iloc[0:11]
# Out:
#       R    G   B
# 0   201  131  40
# 1   201  131  40
# 2   201  131  40
# 3   201  131  40
# 4   201  131  40
# 5   201  131  40
# 6   201  131  40
# 7   201  131  40
# 8   201  131  40
# 9   201  131  40
# 10  201  131  40

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# #### Obtain the distinct values across `Type 1` and `Type 2`.
#
# Exctract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
# He descargado el archivo en mi ordenador
pokemon_csv = pd.read_csv('../../dataframe-calculations/Pokemon.csv')

# %%
pokemon_csv.info() #hago infor para ver el nombre de las columnas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
cols23= np.array(pokemon_csv.loc[:, ['Type 1','Type 2']])

# %%
print(cols23)
# Out:
# [['Grass' 'Poison']
#  ['Grass' 'Poison']
#  ['Grass' 'Poison']
#  ...
#  ['Psychic' 'Ghost']
#  ['Psychic' 'Dark']
#  ['Fire' 'Water']]

# %%
type(cols23)
# Out:
# numpy.ndarray

# %% [markdown]
# #### Cleanup `Name` that contain "Mega".
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
#Reviso el código
print(set(pokemon_csv['Name']))
print(type(pokemon_csv['Name']))
# test transformed data
# Out:
# {'Magcargo', 'Drilbur', 'Bisharp', 'Lugia', 'Weavile', 'Grumpig', 'Pikachu', 'Gothita', 'Haunter', 'Groudon', 'Deino', 'Spiritomb', 'Aerodactyl', 'Shellos', 'MetagrossMega Metagross', 'Shuckle', 'Sigilyph', 'Litwick', 'Politoed', 'Ambipom', 'Bellossom', 'DeoxysNormal Forme', 'Fearow', 'GiratinaOrigin Forme', 'Venonat', 'Chatot', 'Dusclops', 'DiancieMega Diancie', 'Bonsly', 'MewtwoMega Mewtwo Y', 'Aron', 'Skarmory', 'Venipede', 'Gothitelle', 'Butterfree', 'Pichu', 'Tentacool', 'Diggersby', 'Clawitzer', 'Squirtle', 'Musharna', 'Beedrill', 'Crobat', 'Magmar', 'Ampharos', 'Swoobat', 'Hawlucha', 'Dialga', 'Sandslash', 'Armaldo', 'Golett', 'Yanmega', 'Phanpy', 'Gurdurr', 'Chesnaught', 'Slugma', 'Palpitoad', 'Tauros', 'Gabite', 'Crustle', 'Lickilicky', 'Kabuto', 'Drapion', 'Electrode', 'KeldeoResolute Forme', 'Dugtrio', 'Pineco', 'Oshawott', 'LandorusTherian Forme', 'Octillery', 'Elekid', 'Sudowoodo', 'Goldeen', 'Misdreavus', 'Scolipede', 'Lairon', 'AegislashBlade Forme', 'Dewgong', 'Houndo
# ...

# %%
#NO VALIDO
#for x in range(len(pokemon_csv['Name'])):
 #   if 'Mega' in pokemon_csv['Name'][x]:
  #      pokemon_csv['Name'][x]=re.sub("/\w+Mega/gm","Mega", pokemon_csv['Name'][x])

# %%
pokemon_csv['Name']= re.sub("\w+Mega","Mega ", str(pokemon_csv['Name'])) 
#He tenido que pasarlo a string porque sino me daba este error "TypeError: expected string or bytes-like object"

# %%
pokemon_csv['Name'].unique()
# Out:
# array(['0                  Bulbasaur\n1                    Ivysaur\n2                   Venusaur\n3      Mega  Venusaur\n4                 Charmander\n               ...          \n795                  Diancie\n796      Mega  Diancie\n797      HoopaHoopa Confined\n798       HoopaHoopa Unbound\n799                Volcanion\nName: Name, Length: 800, dtype: object'],
#       dtype=object)

# %%
pokemon_csv
# Out:
#        #                                               Name   Type 1  Type 2  \
# 0      1  0                  Bulbasaur\n1               ...    Grass  Poison
# 1      2  0                  Bulbasaur\n1               ...    Grass  Poison
# 2      3  0                  Bulbasaur\n1               ...    Grass  Poison
# 3      3  0                  Bulbasaur\n1               ...    Grass  Poison
# 4      4  0                  Bulbasaur\n1               ...     Fire     NaN
# ..   ...                                                ...      ...     ...
# 795  719  0                  Bulbasaur\n1               ...     Rock   Fairy
# 796  719  0                  Bulbasaur\n1               ...     Rock   Fairy
# 797  720  0                  Bulbasaur\n1               ...  Psychic   Ghost
# 798  720  0                  Bulbasaur\n1               ...  Psychic    Dark
# 799  721  0                  Bulbasaur\n1               ...     Fire   Water
#
# ...

# %% [markdown]
# #### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`.
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
# Respuesta
pokemon_2= pd.read_csv('../../dataframe-calculations/Pokemon.csv')
pokemon_2= pd.DataFrame(pokemon_2)

# %%
pokemon_2['A/D Ratio'] = pokemon_2['Attack']/pokemon_2['Defense']
pokemon_2
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# #### Identify the pokemon with the highest `A/D Ratio`.

# %%
pokemon_2['A/D Ratio'].max()
# Out:
# 9.0

# %%
pokemon_2[pokemon_2['A/D Ratio']== 9.00][["Name", "A/D Ratio"]]
# Out:
#                    Name  A/D Ratio
# 429  DeoxysAttack Forme        9.0

# %%
pokemon_2[pokemon_2['A/D Ratio']== pokemon_2['A/D Ratio'].max()][["Name", "A/D Ratio"]]
#Esta era la forma inicial que yo tenía, le he añadido la parte de las columnas
# Out:
#                    Name  A/D Ratio
# 429  DeoxysAttack Forme        9.0

# %% [markdown]
# #### Identify the pokemon with the lowest A/D Ratio.

# %%
#Respuesta
pokemon_2['A/D Ratio'].min()
# Out:
# 0.043478260869565216

# %%
pokemon_2[pokemon_2['A/D Ratio']== 0.043478260869565216][["Name", "A/D Ratio"]]
# Out:
#         Name  A/D Ratio
# 230  Shuckle   0.043478

# %%
pokemon_2[pokemon_2['A/D Ratio']== pokemon_2['A/D Ratio'].min()][["Name", "A/D Ratio"]]
#Esta era la forma inicial que yo tenía, le he añadido la parte de las columnas
# Out:
#         Name  A/D Ratio
# 230  Shuckle   0.043478

# %% [markdown]
# #### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
#RESPUESTA
pokemon_2['Combo Type']= pokemon_2['Type 1'] + " " + pokemon_2['Type 2']
pokemon_2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[146], line 2
#       1 #RESPUESTA
# ----> 2 pokemon_2['Combo Type']= pokemon_2['Type 1'] + " " + pokemon_2['Type 2'](numeric_only=None)
#       3 pokemon_2
#
# TypeError: 'Series' object is not callable

# %% [markdown]
# #### Identify the pokemon whose `A/D Ratio` are among the top 5.

# %%
#ordeno el dataFrame por orden ascendente según la columna A/D Ratio.

by_AD = pokemon_2.sort_values('A/D Ratio', ascending=True, )

# %%
by_AD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 800 entries, 230 to 429
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
#  13  A/D Ratio   800 non-null    float64
#  14  Combo Type  414 non-null    object
# dtypes: bool(1), float64(1), int64(9), object(4)
# memory usage: 94.5+ KB

# %%
by_AD['A/D Ratio'].max(numeric_only=None)
# Out:
# 9.0

# %%
#Utilizo la lista ordenada por orden ascendente para coger los valores de las últimas cinco filas. 
# Esta era la forma inicial que yo tenía, he modificado para que solo salgan las dos columnas.
pokemon_may_AD= by_AD[795:801][["Name", "A/D Ratio"]]
pokemon_may_AD
# Out:
#                       Name  A/D Ratio
# 428     DeoxysNormal Forme      3.000
# 453               Cranidos      3.125
# 19   BeedrillMega Beedrill      3.750
# 347               Carvanha      4.500
# 429     DeoxysAttack Forme      9.000

# %%
by_AD.tail(5)[["Name", "A/D Ratio"]]
# Out:
#                       Name  A/D Ratio
# 428     DeoxysNormal Forme      3.000
# 453               Cranidos      3.125
# 19   BeedrillMega Beedrill      3.750
# 347               Carvanha      4.500
# 429     DeoxysAttack Forme      9.000

# %% [markdown]
# #### For the 5 pokemon printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemon with the highest `A/D Ratio`.

# %%
#En el ejercicio anterior ya había incluido todas las columnas
#Creo una variable para almacenar los valores únicos de esa columna

# %%
by_AD.tail(5)[["Name", "A/D Ratio", "Combo Type"]]
# Out:
#                       Name  A/D Ratio  Combo Type
# 428     DeoxysNormal Forme      3.000         NaN
# 453               Cranidos      3.125         NaN
# 19   BeedrillMega Beedrill      3.750  Bug Poison
# 347               Carvanha      4.500  Water Dark
# 429     DeoxysAttack Forme      9.000         NaN

# %%
uniquevalues= (by_AD.tail(5)["Combo Type"].unique())
uniquevalues
# Out:
# array([nan, 'Bug Poison', 'Water Dark'], dtype=object)

# %% [markdown]
# #### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemon.
#
# Your output should look like below:
#
# ![Aggregate](../images/aggregated-mean.png)

# %%
# your code here
#new_df_pokemon= pd.DataFrame(by_AD, index= ['Combo Type'])
#new_df_pokemon

#, 'HP', 'Attack', 'Defense','Sp.Atk', 'Sp.Def','Speed', 'Generation', 'Legendary', 'A/D Ratio'

# %%
#Creo un nuevo dataFrame para guardar la lista ordenada por Combo Type en función de su media. 
df_combo= by_AD.groupby('Combo Type').agg(np.mean)
df_combo
# Out:
# /var/folders/8h/kk_7h3_s4y11kgj5jm9784d00000gn/T/ipykernel_2541/3376759682.py:1: FutureWarning: The operation <function mean at 0x7f792e7c3430> failed on a column. If any error is raised, this will raise an exception in a future version of pandas. Drop these columns to avoid this warning.
#   df_combo= by_AD.groupby('Combo Type').agg(np.mean)
#                         #       Total         HP      Attack     Defense  \
# Combo Type
# Bug Electric   595.500000  395.500000  60.000000   62.000000   55.000000
# Bug Fighting   214.000000  550.000000  80.000000  155.000000   95.000000
# Bug Fire       636.500000  455.000000  70.000000   72.500000   60.000000
# Bug Flying     286.285714  419.500000  63.000000   70.142857   61.571429
# Bug Ghost      292.000000  236.000000   1.000000   90.000000   45.000000
# ...                   ...         ...        ...         ...         ...
# Water Ice      103.000000  511.666667  90.000000   83.333333  113.333333
# ...

# %%
df_combo = df_combo.sort_values('A/D Ratio', ascending=True,)
#Vuelvo a ordenar los valores para luego coger los 5 top sobre la media
#No he sabido hacerlo sobre los 5 que filtré previamente

# %%
#INTENTO NO CONSEGUIDO
#Con este código intentaba sacar los valores únicos del dataframe de la media. 
#df_combo_uniquevalues= (df_combo.tail(5)["Combo Type"].unique())
#uniquevalues= (by_AD.tail(5)["Combo Type"].unique())
#uniquevalues
# Out:
# array([nan, 'Bug Poison', 'Water Dark'], dtype=object)

# %%
df_combo.tail(5)
#Creo lque esto es lo que pide la cuestión, pero creo que los datos que coge el COMBO TYPE no son los que debería coger.
#SUpongo que debería coger los valores únicos del ejercicio anterior.
# Out:
#                        #       Total          HP  Attack    Defense  \
# Combo Type
# Rock Flying   354.250000  524.500000   72.500000   123.0  65.000000
# Bug Ghost     292.000000  236.000000    1.000000    90.0  45.000000
# Ground Steel  530.000000  508.000000  110.000000   135.0  60.000000
# Water Dark    347.666667  493.833333   69.166667   120.0  65.166667
# Psychic Dark  720.000000  680.000000   80.000000   160.0  60.000000
#
#                  Sp. Atk  Sp. Def       Speed  Generation  Legendary  \
# Combo Type
# Rock Flying    79.000000     70.0  115.000000    3.000000        0.0
# Bug Ghost      30.000000     30.0   40.000000    3.000000        0.0
# Ground Steel   50.000000     65.0   88.000000    5.000000        0.0
# Water Dark     88.833333     63.5   87.166667    3.166667        0.0
# Psychic Dark  170.000000    130.0   80.000000    6.000000        1.0
#
#               A/D Ratio
# Combo Type
# Rock Flying    1.961589
# Bug Ghost      2.000000
# Ground Steel   2.250000
# ...

# %%
#Este es otro intento fallido de sacar los valroes únicos
uniquevalues.tail(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[172], line 1
# ----> 1 uniquevalues.tail(5)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'tail'

# %%
#Además creo que en alguna parte del LAB tendría que haber quitado los valores nulos de las columnas y no he hecho eso.
